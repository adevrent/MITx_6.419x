# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

filepath = r"C:\Users\adevr\MITx_6.419x\MITx 6.86x\week_6\netflix\toy_data.txt"
X = np.loadtxt('toy_data.txt')
print("type(X) =", type(X))  # type is numpy array
print("X.shape =", X.shape)  # (250, 2)
print("X =\n", X[:10])  # print first 20 lines of data
# Out:
# C:\Users\adevr\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# type(X) = <class 'numpy.ndarray'>
# X.shape = (250, 2)
# X =
#  [[-1.636  2.413]
#  [-2.957  2.296]
#  [-2.871  1.832]
#  [-2.696  1.327]
#  [-2.272  1.738]
#  [-2.393  1.729]
#  [-1.762  2.649]
#  [-2.598  1.345]
#  [-2.02   2.239]
#  [-2.398  2.449]]

# %% [markdown]
# We have an array of $2$ dimensional data points, $X$. Now we plot our data points:

# %%
plt.scatter(X[:, 0], X[:, 1])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       4 K_arr = [1, 2, 3, 4]
#       5 mixtures = [common.init(X, K, seed) for seed, K in enumerate(K_arr)]
# ----> 6 post_arr = [kmeans.run(X, mixture, 0.5) for mixture in mixtures]
#       7 print("post_arr =", post_arr)
#
# Cell In[3], line 6, in <listcomp>(.0)
#       4 K_arr = [1, 2, 3, 4]
#       5 mixtures = [common.init(X, K, seed) for seed, K in enumerate(K_arr)]
# ----> 6 post_arr = [kmeans.run(X, mixture, 0.5) for mixture in mixtures]
#       7 print("post_arr =", post_arr)
#
# File c:\Users\adevr\MITx_6.419x\MITx 6.86x\week_6\netflix\kmeans.py:84, in run(X, mixture, post)
#      82 while (prev_cost is None or prev_cost - cost > 1e-4):
#      83     prev_cost = cost
# ---> 84     post = estep(X, mixture)
#      85     mixture, cost = mstep(X, post)
#      87 return mixture, post, cost
#
# File c:\Users\adevr\MITx_6.419x\MITx 6.86x\week_6\netflix\kmeans.py:21, in estep(X, mixture)
#       8 """E-step: Assigns each datapoint to the gaussian component with the
#       9 closest mean
#      10
#    (...)
#      18
#      19     """
#      20 n, _ = X.shape
# ---> 21 K, _ = mixture.mu.shape
#      22 post = np.zeros((n, K))
#      24 for i in range(n):
#
# AttributeError: 'tuple' object has no attribute 'mu'
