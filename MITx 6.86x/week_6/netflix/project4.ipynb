# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

filepath = r"C:\Users\adevr\MITx_6.419x\MITx 6.86x\week_6\netflix\toy_data.txt"
X = np.loadtxt('toy_data.txt')
print("type(X) =", type(X))  # type is numpy array
print("X.shape =", X.shape)  # (250, 2)
print("X =\n", X[:10])  # print first 20 lines of data
# Out:
# C:\Users\adevr\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# type(X) = <class 'numpy.ndarray'>
# X.shape = (250, 2)
# X =
#  [[-1.636  2.413]
#  [-2.957  2.296]
#  [-2.871  1.832]
#  [-2.696  1.327]
#  [-2.272  1.738]
#  [-2.393  1.729]
#  [-1.762  2.649]
#  [-2.598  1.345]
#  [-2.02   2.239]
#  [-2.398  2.449]]

# %% [markdown]
# We have an array of $2$ dimensional data points, $X$. Now we plot our data points:

# %%
plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TL;DR
#
# E step updates the posterior $ p(j | i): $ P($x_i$ is generated by cluster $j$)
#
# M step updates the $\theta = (\mu_1, \cdots, \mu_K, \sigma_1^2, \cdots, \sigma_K^2, \pi_1, \cdots, \pi_K) $ parameters by maximizing $\hat{l}$ using the $p(j|i)$ values from previous step.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# __________________

# %% [markdown]
# # Gaussian Mixture class
#
# ![image.png](attachment:image.png)
#
# ## Multivariate Gaussian PDF
#
# ![image-2.png](attachment:image-2.png)

# %%
p = np.array([1, 2, 3, 4])
p = p.reshape(1, -1)
p.shape
# Out:
# (1, 4)

# %% [markdown]
# # Log of the posterior probability
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
